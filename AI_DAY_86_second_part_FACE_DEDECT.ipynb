# %%
# FACE DEDECT


import cv2
input= cv2.imread('ELE 1 .jpeg')
cv2.imshow('Test Elephant Image',input)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # FACE DEDECT

# %%
import cv2
face_classifier=cv2.CascadeClassifier('haarcascade_frontalface_default (1) (1).xml')
image=cv2.imread('MODI.jpeg')
gray=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

faces=face_classifier.detectMultiScale(gray,1.3,5)

if len(faces)==0:
    print('no faces found')


for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)
    cv2.imshow('Face dectection',image)
    cv2.waitKey(0)
cv2.destroyAllWindows()
