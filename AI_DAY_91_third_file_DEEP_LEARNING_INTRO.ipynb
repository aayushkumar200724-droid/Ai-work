# %%
# DEEP LEARNING INTRO
pip install keras

# %%
# importing library
import keras as K

# %%
K.__version__
# Out:
# '3.13.2'

# %%
# 1. Define your model = create a sequence and add layers.
# 2. Complie your model. Specify loss functions and optimizers.
# 3. Fit your model. Exccute the model using data.
# 4. Make predictions. Use the model to generate predictions on new data.

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy

numpy.random.seed(7)

# %%
data = numpy.loadtxt("keras.csv", delimiter=",")
x = data[:,0:8]
y = data[:,8]

# %%
# step 1 -- define model
model = Sequential()
model.add(Dense(12, input_dim= 8, activation= 'relu'))
model.add(Dense(8, activation= 'relu'))
model.add(Dense(1, activation= 'sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#  step 2 -- compile model
model.compile(loss= 'binary_crossentropy', optimizer= 'adam', metrics= ['accuracy'])

# %%
# step 3   fit the model
histroy = model.fit(x,y, epochs=150, batch_size=10, verbose=1)
# Out:
# Epoch 1/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3568 - loss: 26.0294
# Epoch 2/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5807 - loss: 1.7922
# Epoch 3/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6484 - loss: 0.7480
# Epoch 4/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6510 - loss: 0.7361
# Epoch 5/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6471 - loss: 0.7268
# Epoch 6/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6510 - loss: 0.7174
# Epoch 7/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6471 - loss: 0.7082
# Epoch 8/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6497 - loss: 0.6993
# Epoch 9/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6497 - loss: 0.6936
# Epoch 10/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6510 - loss: 0.6878
# Epoch 11/150
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6497 - loss: 0.6821
# Epoch 12/150
# ...

# %%
# evaluate the model
scores = model.evaluate(x, y)
print((model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6510 - loss: 0.6468
# ('compile_metrics', 65.10416865348816)

# %%
# calculate predictions
predictions = model.predict(X)
rounded = [round(x[0]) for x in predictions]
print(rounded)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ...
